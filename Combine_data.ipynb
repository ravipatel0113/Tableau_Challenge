# %%
import pandas as pd

# %%
data_2020_06 = "Data/JC-202006-citibike-tripdata.csv"
data_2020_07 = "Data/JC-202007-citibike-tripdata.csv"
data_2020_08 = "Data/JC-202008-citibike-tripdata.csv"
data_2020_09 = "Data/JC-202009-citibike-tripdata.csv"
data_2020_10 = "Data/JC-202010-citibike-tripdata.csv"
data_2020_11 = "Data/JC-202011-citibike-tripdata.csv"
data_2020_12 = "Data/JC-202012-citibike-tripdata.csv"
# data_2021_01 = "Data/JC-202101-citibike-tripdata.csv"
# data_2021_02 = "Data/JC-202102-citibike-tripdata.csv"
# data_2021_03 = "Data/JC-202103-citibike-tripdata.csv"
# data_2021_04 = "Data/JC-202104-citibike-tripdata.csv"
# data_2021_05 = "Data/JC-202105-citibike-tripdata.csv"

# %%
all_data = [data_2020_06, data_2020_07, data_2020_08, data_2020_09, data_2020_10, data_2020_11, data_2020_12]

# %%
data_list = []

for all_d in all_data:
    data_list.append(pd.read_csv(all_d));

# %%
bike_data = pd.concat(data_list, sort=False)
bike_data
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1              1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2               186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3               131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4               266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id          start station name  start station latitude  \
# ...

# %%
bike_data.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  2.357560e+05     235756.000000           235756.000000
# mean   1.689984e+03       3302.922288               40.722159
# std    1.931818e+04        184.290798                0.007440
# min    6.100000e+01       3184.000000               40.709651
# 25%    3.700000e+02       3195.000000               40.716870
# 50%    7.000000e+02       3209.000000               40.721124
# 75%    1.558000e+03       3276.000000               40.727224
# max    3.261756e+06       3792.000000               40.748716
#
#        start station longitude  end station id  end station latitude  \
# count            235756.000000   235756.000000         235756.000000
# mean                -74.046692     3301.259450             40.721592
# std                   0.012048      191.050376              0.118840
# min                 -74.083639       82.000000              0.000000
# ...

# %%
bike_data.to_csv("Data/combine_bike_data.csv")
